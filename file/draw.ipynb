# %%
import matplotlib.pyplot as plt
x = [256, 512, 768, 1024, 1.1*1024, 1.2*1024, 1.3*1024, 1.4*1024, 1.5*1024, 1.6*1024, 1.7*1024, 1.8*1024, 1.9*1024, 2048, 2.5*1024, 3*1024, 3.5*1024, 4096]
y = [4347, 4338, 4365, 4370, 6833, 6882, 7494, 7803, 8012, 8112, 7908, 8470, 8309, 10901, 10985, 13646, 13384, 13618]
plt.plot(x, y)
plt.xlabel('file size in MB')
plt.ylabel('average cpu cycles reading a 4K block')
plt.show()

# %%
x = [16, 32, 64, 128, 256, 384, 512, 640, 768, 896, 1024]
y1 = [13968, 12513, 12639, 11937, 12023, 12601, 12121, 12450, 12603, 12950, 12485]
y2 = [15918, 15360, 15824, 14300, 14242, 15403, 14326, 14826, 14352, 14440, 14230]
plt.xlabel('file size in MB')
plt.ylabel('average cpu cycles reading a 4K block')
plt.plot(x, y1)
plt.plot(x, y2)
plt.show()

# %%
x = [1, 2, 3, 4, 5, 6, 7, 8]
y = [12785, 18864, 30164, 31103, 37586, 44340, 52426, 62050]
plt.xlabel('Process Number')
plt.ylabel('Average cpu cycles reading a 4K block')
plt.plot(x, y)
plt.show()
